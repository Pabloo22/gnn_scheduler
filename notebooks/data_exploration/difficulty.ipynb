# %%
from gnn_scheduler.jssp import load_all_from_benchmark, CPSolver

# %%
instances = load_all_from_benchmark()
len(instances)
# Out:
# 162

# %%
# We compute the max_bounds using the CP solver set to 0.1s
# We use the CP solver to compute the max_bound
# max_bounds = []
# for instance in instances:
#     solver = CPSolver(instance, time_limit=0.1)
#     solution = solver.solve()
#     if solution is not None:
#         print("instance: ", 
#               instance.name, "makespan: ", 
#               solution.get("makespan", None),
#               "optimum: ", instance.optimum)
#         if "makespan" in solution:
#             difficulty = solution["makespan"] - instance.lower_bound
#             print("difficulty: ", difficulty)
#         print("------------------")
#         max_bounds.append(solution.get("makespan", None))
#     else:
#         print("instance: ", instance.name, "unsolved")
#         print("------------------")
#         max_bounds.append(None)

# %%
from multiprocessing import Pool

def solve_instance(instance_index):
    index, instance = instance_index
    solver = CPSolver(instance, time_limit=0.2)
    solution = solver.solve()
    msg = ""
    if solution is not None:
        makespan = solution.get("makespan", None)
        difficulty = makespan - instance.lower_bound if "makespan" in solution else None
        result = index, instance.name, makespan, instance.optimum, difficulty
    else:
        result = index, instance.name, None, None, None

    if result[2] is not None:  # Makespan is not None
        msg += f"instance: {result[1]} makespan: {result[2]} optimum: {result[3]}"
        if result[4] is not None:  # Difficulty is not None
            # print("difficulty: ", result[3])
            msg += f" difficulty: {result[4]}"
    else:
        # print("instance: ", result[0], "unsolved")
        msg += f"instance: {result[1]} unsolved"
    # print("------------------")
    msg += "\n------------------"
    print(msg)    
    return result

# %%
with Pool(processes=1) as pool:
        indexed_instances = list(enumerate(instances))
        results = pool.map(solve_instance, indexed_instances)
        results.sort()  # Sorting by the first element of each tuple, which is the index
        max_bounds = [result[2] for result in results]
# Out:
# instance: abz5 makespan: 1337 optimum: 1234 difficulty: 103
# ------------------
# instance: abz6 makespan: 947 optimum: 943 difficulty: 4
# ------------------
# instance: abz7 unsolved
# ------------------
# instance: abz8 unsolved
# ------------------
# instance: abz9 makespan: 861 optimum: 678 difficulty: 183
# ------------------
# instance: ft06 makespan: 55 optimum: 55 difficulty: 0
# ------------------
# instance: ft10 makespan: 1076 optimum: 930 difficulty: 146
# ------------------
# instance: ft20 makespan: 1389 optimum: 1165 difficulty: 224
# ------------------
# instance: la01 makespan: 666 optimum: 666 difficulty: 0
# ------------------
# instance: la02 makespan: 683 optimum: 655 difficulty: 28
# ------------------
# instance: la03 makespan: 636 optimum: 597 difficulty: 39
# ------------------
# instance: la04 makespan: 634 optimum: 590 difficulty: 44
# ------------------
# instance: la05 makespan: 593 optimum: 593 difficulty: 0
# ------------------
# instance: la06 makespan: 926 optimum: 926 difficulty: 0
# ------------------
# instance: la07 makespan: 890 optimum: 890 difficulty: 0
# ------------------
# instance: la08 makespan: 863 optimum: 863 difficulty: 0
# ------------------
# instance: la09 makespan: 951 optimum: 951 difficulty: 0
# ------------------
# instance: la10 makespan: 958 optimum: 958 difficulty: 0
# ------------------
# instance: la11 makespan: 1222 optimum: 1222 difficulty: 0
# ------------------
# instance: la12 makespan: 1092 optimum: 1039 difficulty: 53
# ------------------
# instance: la13 makespan: 1150 optimum: 1150 difficulty: 0
# ------------------
# instance: la14 makespan: 1292 optimum: 1292 difficulty: 0
# ------------------
# instance: la15 makespan: 1288 optimum: 1207 difficulty: 81
# ------------------
# instance: la16 makespan: 1018 optimum: 945 difficulty: 73
# ------------------
# instance: la17 makespan: 797 optimum: 784 difficulty: 13
# ------------------
# instance: la18 makespan: 938 optimum: 848 difficulty: 90
# ------------------
# instance: la19 makespan: 962 optimum: 842 difficulty: 120
# ------------------
# instance: la20 makespan: 930 optimum: 902 difficulty: 28
# ------------------
# instance: la21 makespan: 1255 optimum: 1046 difficulty: 209
# ------------------
# instance: la22 makespan: 1029 optimum: 927 difficulty: 102
# ------------------
# instance: la23 makespan: 1137 optimum: 1032 difficulty: 105
# ------------------
# instance: la24 makespan: 1053 optimum: 935 difficulty: 118
# ------------------
# instance: la25 makespan: 1084 optimum: 977 difficulty: 107
# ------------------
# instance: la26 makespan: 1431 optimum: 1218 difficulty: 213
# ------------------
# instance: la27 makespan: 1442 optimum: 1235 difficulty: 207
# ------------------
# instance: la28 makespan: 1425 optimum: 1216 difficulty: 209
# ------------------
# instance: la29 makespan: 1337 optimum: 1152 difficulty: 185
# ------------------
# instance: la30 makespan: 1573 optimum: 1355 difficulty: 218
# ------------------
# instance: la31 makespan: 1931 optimum: 1784 difficulty: 147
# ------------------
# instance: la32 makespan: 1875 optimum: 1850 difficulty: 25
# ------------------
# instance: la33 makespan: 1875 optimum: 1719 difficulty: 156
# ------------------
# instance: la34 makespan: 1935 optimum: 1721 difficulty: 214
# ------------------
# instance: la35 makespan: 2082 optimum: 1888 difficulty: 194
# ------------------
# instance: la36 makespan: 1507 optimum: 1268 difficulty: 239
# ------------------
# instance: la37 makespan: 1562 optimum: 1397 difficulty: 165
# ------------------
# instance: la38 makespan: 1405 optimum: 1196 difficulty: 209
# ------------------
# instance: la39 makespan: 1465 optimum: 1233 difficulty: 232
# ------------------
# instance: la40 makespan: 1413 optimum: 1222 difficulty: 191
# ------------------
# instance: orb01 makespan: 1278 optimum: 1059 difficulty: 219
# ------------------
# instance: orb02 makespan: 922 optimum: 888 difficulty: 34
# ------------------
# instance: orb03 makespan: 1096 optimum: 1005 difficulty: 91
# ------------------
# instance: orb04 makespan: 1096 optimum: 1005 difficulty: 91
# ------------------
# instance: orb05 makespan: 927 optimum: 887 difficulty: 40
# ------------------
# instance: orb06 makespan: 1186 optimum: 1010 difficulty: 176
# ------------------
# instance: orb07 makespan: 444 optimum: 397 difficulty: 47
# ------------------
# instance: orb08 makespan: 1042 optimum: 899 difficulty: 143
# ------------------
# instance: orb09 makespan: 1033 optimum: 934 difficulty: 99
# ------------------
# instance: orb10 makespan: 1133 optimum: 944 difficulty: 189
# ------------------
# instance: swv01 makespan: 1988 optimum: 1407 difficulty: 581
# ------------------
# instance: swv02 makespan: 1966 optimum: 1475 difficulty: 491
# ------------------
# instance: swv03 makespan: 1863 optimum: 1398 difficulty: 465
# ------------------
# instance: swv04 makespan: 1875 optimum: 1464 difficulty: 411
# ------------------
# instance: swv05 makespan: 1811 optimum: 1424 difficulty: 387
# ------------------
# instance: swv06 makespan: 2164 optimum: None difficulty: 534
# ------------------
# instance: swv07 makespan: 2115 optimum: None difficulty: 602
# ------------------
# instance: swv08 makespan: 2544 optimum: None difficulty: 873
# ------------------
# instance: swv09 makespan: 2118 optimum: None difficulty: 485
# ------------------
# instance: swv10 makespan: 2300 optimum: None difficulty: 637
# ------------------
# instance: swv11 unsolved
# ------------------
# instance: swv12 unsolved
# ------------------
# instance: swv13 unsolved
# ------------------
# instance: swv14 unsolved
# ------------------
# instance: swv15 unsolved
# ------------------
# instance: swv16 unsolved
# ------------------
# instance: swv17 unsolved
# ------------------
# instance: swv18 unsolved
# ------------------
# instance: swv19 unsolved
# ------------------
# instance: swv20 unsolved
# ------------------
# instance: yn1 unsolved
# ------------------
# instance: yn2 unsolved
# ------------------
# instance: yn3 unsolved
# ------------------
# instance: yn4 unsolved
# ------------------
# instance: ta01 makespan: 1473 optimum: 1231 difficulty: 242
# ------------------
# instance: ta02 makespan: 1404 optimum: 1244 difficulty: 160
# ------------------
# instance: ta03 makespan: 1401 optimum: 1218 difficulty: 183
# ------------------
# instance: ta04 makespan: 1382 optimum: 1175 difficulty: 207
# ------------------
# instance: ta05 makespan: 1488 optimum: 1224 difficulty: 264
# ------------------
# instance: ta06 makespan: 1369 optimum: 1238 difficulty: 131
# ------------------
# instance: ta07 makespan: 1469 optimum: 1227 difficulty: 242
# ------------------
# instance: ta08 makespan: 1443 optimum: 1217 difficulty: 226
# ------------------
# instance: ta09 makespan: 1541 optimum: 1274 difficulty: 267
# ------------------
# instance: ta10 makespan: 1534 optimum: 1241 difficulty: 293
# ------------------
# instance: ta11 unsolved
# ------------------
# instance: ta12 unsolved
# ------------------
# instance: ta13 unsolved
# ------------------
# instance: ta14 unsolved
# ------------------
# instance: ta15 unsolved
# ------------------
# instance: ta16 unsolved
# ------------------
# instance: ta17 unsolved
# ------------------
# instance: ta18 unsolved
# ------------------
# instance: ta19 unsolved
# ------------------
# instance: ta20 unsolved
# ------------------
# instance: ta21 unsolved
# ------------------
# instance: ta22 unsolved
# ------------------
# instance: ta23 unsolved
# ------------------
# instance: ta24 unsolved
# ------------------
# instance: ta25 unsolved
# ------------------
# instance: ta26 unsolved
# ------------------
# instance: ta27 unsolved
# ------------------
# instance: ta28 unsolved
# ------------------
# instance: ta29 unsolved
# ------------------
# instance: ta30 unsolved
# ------------------
# instance: ta31 unsolved
# ------------------
# instance: ta32 unsolved
# ------------------
# instance: ta33 unsolved
# ------------------
# instance: ta34 unsolved
# ------------------
# instance: ta35 unsolved
# ------------------
# instance: ta36 unsolved
# ------------------
# instance: ta37 unsolved
# ------------------
# instance: ta38 unsolved
# ------------------
# instance: ta39 unsolved
# ------------------
# instance: ta40 unsolved
# ------------------
# instance: ta41 unsolved
# ------------------
# instance: ta42 unsolved
# ------------------
# instance: ta43 unsolved
# ------------------
# instance: ta44 unsolved
# ------------------
# instance: ta45 unsolved
# ------------------
# instance: ta46 unsolved
# ------------------
# instance: ta47 unsolved
# ------------------
# instance: ta48 unsolved
# ------------------
# instance: ta49 unsolved
# ------------------
# instance: ta50 unsolved
# ------------------
# instance: ta51 unsolved
# ------------------
# instance: ta52 unsolved
# ------------------
# instance: ta53 unsolved
# ------------------
# instance: ta54 unsolved
# ------------------
# instance: ta55 unsolved
# ------------------
# instance: ta56 unsolved
# ------------------
# instance: ta57 unsolved
# ------------------
# instance: ta58 unsolved
# ------------------
# instance: ta59 unsolved
# ------------------
# instance: ta60 unsolved
# ------------------
# instance: ta61 unsolved
# ------------------
# instance: ta62 unsolved
# ------------------
# instance: ta63 unsolved
# ------------------
# instance: ta64 unsolved
# ------------------
# instance: ta65 unsolved
# ------------------
# instance: ta66 unsolved
# ------------------
# instance: ta67 unsolved
# ------------------
# instance: ta68 unsolved
# ------------------
# instance: ta69 unsolved
# ------------------
# instance: ta70 unsolved
# ------------------
# instance: ta71 unsolved
# ------------------
# instance: ta72 unsolved
# ------------------
# instance: ta73 unsolved
# ------------------
# instance: ta74 unsolved
# ------------------
# instance: ta75 unsolved
# ------------------
# instance: ta76 unsolved
# ------------------
# instance: ta77 unsolved
# ------------------
# instance: ta78 unsolved
# ------------------
# instance: ta79 unsolved
# ------------------
# instance: ta80 unsolved
# ------------------

# %%
import pandas as pd

# Create a dataframe with columns: name, n_jobs, n_machines, max_bound, lower_bound, optimum
names = [instance.name for instance in instances]
n_jobs = [instance.n_jobs for instance in instances]
n_machines = [instance.n_machines for instance in instances]
lower_bounds = [instance.lower_bound for instance in instances]
optimums = [instance.optimum for instance in instances]
df = pd.DataFrame(
    {
        "name": names,
        "n_jobs": n_jobs,
        "n_machines": n_machines,
        "max_bound": max_bounds,
        "lower_bound": lower_bounds,
        "optimum": optimums,
    }
)

# %%
df.head(40)
# Out:
#     name  n_jobs  n_machines  max_bound  lower_bound  optimum
# 0   abz5      10          10     1337.0         1234   1234.0
# 1   abz6      10          10      947.0          943    943.0
# 2   abz7      20          15        NaN          656    656.0
# 3   abz8      20          15        NaN          645      NaN
# 4   abz9      20          15      861.0          678    678.0
# 5   ft06       6           6       55.0           55     55.0
# 6   ft10      10          10     1076.0          930    930.0
# 7   ft20      20           5     1389.0         1165   1165.0
# 8   la01      10           5      666.0          666    666.0
# 9   la02      10           5      683.0          655    655.0
# 10  la03      10           5      636.0          597    597.0
# 11  la04      10           5      634.0          590    590.0
# 12  la05      10           5      593.0          593    593.0
# 13  la06      15           5      926.0          926    926.0
# 14  la07      15           5      890.0          890    890.0
# 15  la08      15           5      863.0          863    863.0
# 16  la09      15           5      951.0          951    951.0
# 17  la10      15           5      958.0          958    958.0
# 18  la11      20           5     1222.0         1222   1222.0
# 19  la12      20           5     1092.0         1039   1039.0
# 20  la13      20           5     1150.0         1150   1150.0
# 21  la14      20           5     1292.0         1292   1292.0
# 22  la15      20           5     1288.0         1207   1207.0
# 23  la16      10          10     1018.0          945    945.0
# 24  la17      10          10      797.0          784    784.0
# 25  la18      10          10      938.0          848    848.0
# 26  la19      10          10      962.0          842    842.0
# 27  la20      10          10      930.0          902    902.0
# 28  la21      15          10     1255.0         1046   1046.0
# 29  la22      15          10     1029.0          927    927.0
# 30  la23      15          10     1137.0         1032   1032.0
# 31  la24      15          10     1053.0          935    935.0
# 32  la25      15          10     1084.0          977    977.0
# 33  la26      20          10     1431.0         1218   1218.0
# 34  la27      20          10     1442.0         1235   1235.0
# 35  la28      20          10     1425.0         1216   1216.0
# 36  la29      20          10     1337.0         1152   1152.0
# 37  la30      20          10     1573.0         1355   1355.0
# 38  la31      30          10     1931.0         1784   1784.0
# 39  la32      30          10     1875.0         1850   1850.0

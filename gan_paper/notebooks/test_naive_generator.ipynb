# %%
from gnn_scheduler.jssp import NaiveGenerator

# %%
generator = NaiveGenerator(
    max_n_jobs=10, max_n_machines=10, max_duration=10, seed=1234
)

# %%
random_instances = []
for _ in range(5):
    random_instances.append(generator.generate())

# %%
for instance in random_instances:
    instance.disjunctive_graph.plot()

# %%
from gnn_scheduler.jssp import DisjunctiveGraph
